# %%
import numpy as np
import math
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy import stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
x=np.array([61,62,66.7,58.9,59,66,59.9,78,64.3,80.3,82.5,59,81,74.4])
sm.graphics.qqplot(x, line='q', alpha=0.5)

# %%
y=np.array([50,41.5,56,36.6,46.4,42.4,53,76.1,59,37.8,82,56.2,66,62])
sm.graphics.qqplot(y, line='q', alpha=0.5)

# %%
z = x - y

# %%
sm.graphics.qqplot(y, line='q', alpha=0.5)

# %%
a=np.array([88.6,73.2,91.4,68,75.2])
sm.graphics.qqplot(a, line='q', alpha=0.5)

# %%
b=np.array([63,53.9,69.2,50.1,71.5])
sm.graphics.qqplot(b, line='q', alpha=0.5)

# %%
c=np.array([44.9,59.5,40.2,56.3,38.7])
sm.graphics.qqplot(c, line='q', alpha=0.5)

# %%
d=np.array([31,39.6,45.3,25.2,22.7])
sm.graphics.qqplot(d, line='q', alpha=0.5)

# %%
stats.levene(a,b,c,d)
# Out:
# LeveneResult(statistic=0.005781754001582374, pvalue=0.9993683789569988)

# %%
stats.f_oneway(a,b,c,d)
# Out:
# F_onewayResult(statistic=21.09222356685044, pvalue=8.324881697746597e-06)

# %%
result=pairwise_tukeyhsd([a,b,c,d],df[a,b,c,d],alpha=0.05)
print(result)
result.plot_simultaneous()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-0bfa28fd9989> in <module>
# ----> 1 result=pairwise_tukeyhsd([a,b,c,d],df[a,b,c,d],alpha=0.05)
#       2 print(result)
#       3 result.plot_simultaneous()
#
# NameError: name 'df' is not defined

# %%
sum = 0
for i in a:
    sum = sum + (i-79.28)**2
for i in b:
    sum = sum + (i-61.54)**2
for i in c:
    sum = sum + (i-47.92)**2
for i in d:
    sum = sum + (i-32.76)**2

# %%
sum/16
# Out:
# 92.96250000000002

# %%
1487.4/16
# Out:
# 92.9625

# %%
4.05*math.sqrt(92.9635/5)
# Out:
# 17.463297562316228

# %%
79.28-32.76
# Out:
# 46.52
